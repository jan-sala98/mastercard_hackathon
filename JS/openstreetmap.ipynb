# %%
import osmnx as ox
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
def get_osm_data(place_name: str, tags: dict):
    """
    Pobiera dane z OpenStreetMap dla danego obszaru i tagów.

    Parameters:
        place_name (str): nazwa lokalizacji np. "Warszawa, Polska"
        tags (dict): słownik tagów OSM np. {"amenity": "parcel_locker"}

    Returns:
        geopandas.GeoDataFrame
    """
    print(f"Pobieranie danych OSM dla: {tags} w lokalizacji: {place_name}")
    gdf = ox.features_from_place(place_name, tags)
    return gdf

# %%
place = "Warszawa, Polska"
tags = {"building": True}

gdf = ox.features_from_place(place, tags)

# Eksploracja dostępnych tagów
print("Dostępne kolumny (tagi):")
for col in gdf.columns:
    if gdf[col].notna().any():
        unique_vals = gdf[col].dropna().unique()
        print(f"{col}: {len(unique_vals)} unikalnych wartości")
        print(f"    Przykładowe: {unique_vals[:5]}\n")
# Out:
# Dostępne kolumny (tagi):
# geometry: 184464 unikalnych wartości
#     Przykładowe: <GeometryArray>
# [<POINT (21.249 52.214)>, <POINT (20.941 52.333)>, <POINT (21.026 52.197)>,
#  <POINT (21.028 52.241)>, <POINT (20.941 52.333)>]
# Length: 5, dtype: geometry
#
# access: 6 unikalnych wartości
#     Przykładowe: ['yes' 'no' 'customers' 'private' 'permissive']
#
# building: 145 unikalnych wartości
#     Przykładowe: ['bunker' 'yes' 'wayside_shrine' 'public' 'ruins']
#
# bunker_type: 5 unikalnych wartości
#     Przykładowe: ['mg_nest' 'gun_emplacement' 'ringstand_58c' 'pillbox'
#  'bunker_type=mg_nest']
#
# historic: 24 unikalnych wartości
#     Przykładowe: ['yes' 'wayside_shrine' 'bunker' 'castle' 'building']
#
# military: 3 unikalnych wartości
#     Przykładowe: ['bunker' 'office' 'yes']
#
# name: 3640 unikalnych wartości
#     Przykładowe: ['Regelbau 514' 'Urząd Pocztowy 139' 'Wgórę' 'Żabka'
#  'Centrum Wspinaczkowe On Sight']
#
# ruins: 4 unikalnych wartości
#     Przykładowe: ['yes' 'bunker' 'industrial' '1']
#
# addr:street: 4760 unikalnych wartości
#     Przykładowe: ['Odkryta' 'Dominika Merliniego' 'Obozowa' 'Hoża' 'Tunelowa']
#
# amenity: 83 unikalnych wartości
#     Przykładowe: ['post_office' 'toilets' 'place_of_worship' 'doctors' 'clinic']
#
# brand: 142 unikalnych wartości
#     Przykładowe: ['Poczta Polska' 'Żabka' 'Decathlon' 'Raffles' 'Castorama']
#
# brand:wikidata: 109 unikalnych wartości
#     Przykładowe: ['Q168833' 'Q2589061' 'Q509349' 'Q966971' 'Q889624']
#
# layer: 6 unikalnych wartości
#     Przykładowe: ['-1' '1' '-2' '3' '2']
#
# opening_hours: 623 unikalnych wartości
#     Przykładowe: ['Mo-Fr 08:00-20:00' 'Mo-Fr 08:00-22:30; Sa-Su 09:00-21:00'
#  'Mo-Su 06:00-23:00' 'Mo-Fr 08:00-21:45; Sa,Su 09:00-21:15'
#  'Mo-Fr 08:00-23:00; Sa,Su 10:00-21:00']
#
# phone: 589 unikalnych wartości
#     Przykładowe: ['+48 22 889 71 04' '+48222453688' '+48 697837198' '+48536221878'
#  '+48 791 585 451']
#
# wheelchair: 4 unikalnych wartości
#     Przykładowe: ['yes' 'limited' 'no' 'designated']
#
# addr:city: 5 unikalnych wartości
#     Przykładowe: ['Warszawa' 'Warsaw' 'Zgorzała' 'Blizne Łaszczyńskiego' 'Łomianki']
#
# addr:housenumber: 7602 unikalnych wartości
#     Przykładowe: ['2' '60' '51' '65' '16']
#
# addr:postcode: 3732 unikalnych wartości
#     Przykładowe: ['02-511' '01-423' '00-681' '03-828' '02-981']
#
# email: 346 unikalnych wartości
#     Przykładowe: ['info@wgore.eu' 'info@crux.boulder.pl' 'info@obiekto.pl'
#  'voltboulderownia@gmail.com' 'warszawa-krakowska@murall.pl']
#
# leisure: 17 unikalnych wartości
#     Przykładowe: ['sports_centre' 'sports_hall' 'ice_rink' 'indoor_play' 'pitch']
#
# official_name: 213 unikalnych wartości
#     Przykładowe: ['Arena Wspinaczkowa Wgórę' 'Wydział Geologii Uniwersytetu Warszawskiego'
#  'Pałac Kultury i Nauki' 'Regent Warsaw Hotel'
#  'Akademik Dom Studencki Politechniki Warszawskiej']
#
# sport: 22 unikalnych wartości
#     Przykładowe: ['climbing' 'swimming' 'ice_skating' 'multi' 'hockey;ice_skating;rollers']
#
# website: 1017 unikalnych wartości
#     Przykładowe: ['http://wgore.eu' 'http://www.obozowa.waw.pl/' 'https://crux.boulder.pl/'
#  'https://obiekto.pl' 'https://www.voltboulderownia.pl/']
#
# description: 223 unikalnych wartości
#     Przykładowe: ['Schron wartowniczy'
#  'pl:piwnica? bunkier? kwadratowa dziura w starym betonie.'
#  'Bunkier poniemiecki' 'Budynek 76'
#  'Zarząd i Urząd Marszałkowski Województwa Mazowieckiego; Departament kultury, promocji i turystyki; Departament nadzoru właścicielskiego i inwestycji']
#
# name:signed: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# tourism: 10 unikalnych wartości
#     Przykładowe: ['attraction' 'museum' 'hotel' 'gallery' 'hostel']
#
# brand:wikipedia: 67 unikalnych wartości
#     Przykładowe: ['pl:Żabka (sieć sklepów)' 'en:Decathlon Group' 'en:Castorama'
#  'en:Leroy Merlin' 'en:IKEA']
#
# check_date: 352 unikalnych wartości
#     Przykładowe: ['2023-09-23' '2024-06-05' '2025-03-09' '2025-02-09' '2024-06-09']
#
# name:en: 225 unikalnych wartości
#     Przykładowe: ['Żabka' 'Volt Bouldering' 'Ujazdów Castle' 'Royal Castle'
#  'Palace of Culture and Science']
#
# name:pl: 87 unikalnych wartości
#     Przykładowe: ['Żabka' 'Ringstand 58c' 'Bunkier Ringstand 58c'
#  'Centrum Bankowo-Finansowe' 'Zamek Królewski']
#
# name:uk: 37 unikalnych wartości
#     Przykładowe: ['Жабка' 'Мазовецьке Воєводське Управління, Місцевий паспортний пункт'
#  'Палац культури і науки' 'Міністерство розвитку і технологій'
#  'Національна бібліотека Польщі']
#
# shop: 96 unikalnych wartości
#     Przykładowe: ['convenience' 'pastry' 'mall' 'sports' 'doityourself']
#
# denomination: 17 unikalnych wartości
#     Przykładowe: ['catholic' 'roman_catholic' 'orthodox' 'polish_catholic' 'lutheran']
#
# religion: 3 unikalnych wartości
#     Przykładowe: ['christian' 'jewish' 'muslim']
#
# climbing:boulder: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# internet_access: 3 unikalnych wartości
#     Przykładowe: ['wlan' 'yes' 'no']
#
# level: 10 unikalnych wartości
#     Przykładowe: ['1;2' '0' '5' '1' '0;-1']
#
# fixme: 49 unikalnych wartości
#     Przykładowe: ['Po zakończeniu budowy proszę pamiętać o access dla bunkrów!!!'
#  'Co to jest?' 'verify description' 'shape' 'do importu obrys']
#
# gez:inscription_date: 11 unikalnych wartości
#     Przykładowe: ['2017-11-13' '2012-07-24' '2017-04-28' '2018-11-19' '2017-09-22']
#
# heritage: 4 unikalnych wartości
#     Przykładowe: ['2' '1' '7' '4']
#
# heritage:operator: 5 unikalnych wartości
#     Przykładowe: ['NID;GEZ' 'nid' 'whc;nid' 'NID' 'GEZ']
#
# nid:inscription_date: 22 unikalnych wartości
#     Przykładowe: ['2017-08-10' '1965-07-01' '2001-04-12' '1984-07-24' '1980-11-10']
#
# ref:gez: 107 unikalnych wartości
#     Przykładowe: ['WOL34555' 'WOL34554' 'WOL34553' 'SRO09571' 'WOL20059']
#
# ref:nid: 79 unikalnych wartości
#     Przykładowe: ['A-1389' '620/1' 'A-735' '242;1244-A' '12-A']
#
# historic:military: 1 unikalnych wartości
#     Przykładowe: ['bunker']
#
# location: 6 unikalnych wartości
#     Przykładowe: ['underground' 'indoor' 'outdoor' 'overground' 'surface']
#
# government: 27 unikalnych wartości
#     Przykładowe: ['administrative' 'ministry' 'social_security' 'audit' 'legislative']
#
# office: 30 unikalnych wartości
#     Przykładowe: ['government' 'financial' 'diplomatic' 'educational_institution'
#  'energy_supplier']
#
# check_date:opening_hours: 71 unikalnych wartości
#     Przykładowe: ['2023-11-07' '2023-01-10' '2024-10-09' '2024-12-02' '2023-02-24']
#
# name:ru: 56 unikalnych wartości
#     Przykładowe: ['Управление Мазовецкого воеводства, Местный паспортный пункт'
#  'Уяздовский замок' 'Королевский замок' 'Дворец культуры и науки'
#  'Министерство развития и технологий']
#
# historic:civilization: 1 unikalnych wartości
#     Przykładowe: ['modern']
#
# description:pl: 4 unikalnych wartości
#     Przykładowe: ['Ceglana, okrągła podstawa o średnicy ~5 m, z kikutem stalowego pręta na środku'
#  'Dom dyrektora Żabińskiego' 'Opuszczona kamienica'
#  'Półkolisty cokół muru']
#
# contact:facebook: 44 unikalnych wartości
#     Przykładowe: ['green_pixie' 'http://www.facebook.com/zamek.krolewski.warszawa'
#  'https://www.facebook.com/palac.kultury.i.nauki'
#  'https://pl-pl.facebook.com/da.swanna/'
#  'https://www.facebook.com/dominikanie.freta/']
#
# contact:instagram: 16 unikalnych wartości
#     Przykładowe: ['https://www.instagram.com/obiekto/'
#  'https://www.instagram.com/royalcastleinwarsaw/'
#  'https://www.instagram.com/palackulturyinauki/'
#  'https://www.instagram.com/da.swanna/'
#  'https://www.instagram.com/policja_ksp/']
#
# alt_name: 152 unikalnych wartości
#     Przykładowe: ['Wolt Boulderownia' 'Hotel Regent Warsaw' 'Wydział Chemiczny'
#  'Arsenał Królewski' 'Budynek G']
#
# facebook: 23 unikalnych wartości
#     Przykładowe: ['https://www.facebook.com/VOLTboulderownia/' 'MurallWarszawa'
#  'https://www.facebook.com/CourtyardWarsawAirport/'
#  'https://www.facebook.com/NasladowcyJezusaChrystusaWarszawa'
#  'TowarzystwoPolskaFinlandia']
#
# disused:shop: 15 unikalnych wartości
#     Przykładowe: ['kiosk' 'yes' 'department_store' 'convenience' 'car_repair']
#
# cuisine: 46 unikalnych wartości
#     Przykładowe: ['ice_cream' 'italian' 'polish' 'asian' 'chicken']
#
# source: 85 unikalnych wartości
#     Przykładowe: ['https://www.twoja-praga.pl/praga/miejsca/2166.html'
#  'www.geoportal.gov.pl' 'landsat' 'Geoportal 2: Ortofotomapa'
#  'local knowledge']
#
# frequency: 2 unikalnych wartości
#     Przykładowe: ['50' '50;0']
#
# operator: 345 unikalnych wartości
#     Przykładowe: ['PGE Energetyka Kolejowa' 'PKP Energetyka' 'Salezjanki (FMA)'
#  'Stoen Operator' 'OSiR Praga-Południe']
#
# operator:wikidata: 63 unikalnych wartości
#     Przykładowe: ['Q7119525' 'Q11833155' 'Q1718656' 'Q608518' 'Q11804513']
#
# operator:wikipedia: 57 unikalnych wartości
#     Przykładowe: ['pl:PKP Energetyka' 'pl:Parafia Najczystszego Serca Maryi w Warszawie'
#  'pl:Parafia św. Józefa Oblubieńca Najświętszej Maryi Panny w Warszawie (Koło)'
#  'pl:Parafia św. Klemensa Hofbauera w Warszawie'
#  'pl:Parafia Świętych Rafała i Alberta w Warszawie']
#
# power: 4 unikalnych wartości
#     Przykładowe: ['substation' 'generator' 'switchgear' 'transformer']
#
# substation: 4 unikalnych wartości
#     Przykładowe: ['minor_distribution' 'distribution' 'traction' 'transmission']
#
# voltage: 9 unikalnych wartości
#     Przykładowe: ['15000;400' '110000;15000' '15000;600' '15000' '110000']
#
# building:levels: 48 unikalnych wartości
#     Przykładowe: ['1' '2' '4' '3' '6']
#
# fee: 3 unikalnych wartości
#     Przykładowe: ['yes' 'no' 'interval']
#
# toilets:position: 3 unikalnych wartości
#     Przykładowe: ['seated' 'urinal;seated' 'seated;urinal']
#
# unisex: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# ref: 1064 unikalnych wartości
#     Przykładowe: ['9595' '11154' '11432' '11443' '12967']
#
# addr:floor: 1 unikalnych wartości
#     Przykładowe: ['G']
#
# payment:cash: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# payment:credit_cards: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# payment:debit_cards: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# inscription: 4 unikalnych wartości
#     Przykładowe: ['św. Katarzyna Aleksandryjska - Patronka Kolejarzy'
#  'Na podziękowanie Bogu że nas przy życiu zachował w śród grassującej cholery w miesiacu sierpniu 1852 r.'
#  'OD | GŁODU OGNIA I WOJNY | WYBAW NAS PANIE'
#  'Krzyż moją ucieczką / 300 dni Odp. Pius IX. – O Ma - ryo ulituj się /nad niedostat - kami/ i nędzami naszemi / i racz im zaradzić. – Fundacja Małżonków / Jana i Marcyan - ny / Pyć / Wrzesień 1916 r.']
#
# admin_level: 2 unikalnych wartości
#     Przykładowe: ['7' '9']
#
# castle_type: 2 unikalnych wartości
#     Przykładowe: ['palace' 'stately']
#
# end_date: 3 unikalnych wartości
#     Przykładowe: ['1679' '1775' '2012']
#
# heritage:website: 15 unikalnych wartości
#     Przykładowe: ['https://zabytek.pl/pl/obiekty/zabytek?inspire_id=PL.1.9.ZIPOZ.NID_N_14_BK.202470&rejestr=rejestr-zabytkow'
#  'https://zabytek.pl/pl/obiekty/zabytek?inspire_id=PL.1.9.ZIPOZ.NID_N_14_BK.188130&rejestr=rejestr-zabytkow'
#  'https://zabytek.pl/pl/obiekty/zabytek?inspire_id=PL.1.9.ZIPOZ.NID_N_14_BK.201696&rejestr=rejestr-zabytkow'
#  'https://zabytek.pl/pl/obiekty/zabytek?inspire_id=PL.1.9.ZIPOZ.NID_N_14_BK.194704&rejestr=rejestr-zabytkow'
#  'https://zabytek.pl/pl/obiekty/zabytek?inspire_id=PL.1.9.ZIPOZ.NID_N_14_BK.202475&rejestr=rejestr-zabytkow']
#
# name:ca: 5 unikalnych wartości
#     Przykładowe: ['Biblioteca Nacional de Polònia' 'Palau de Wilanów' 'Edifici A'
#  'Teatre Polonès' 'Institut Frédéric Chopin']
#
# name:cs: 20 unikalnych wartości
#     Przykładowe: ['Královský hrad' 'Ministerstvo rozvoje a technologií'
#  'Polská národní knihovna' 'Polská národní banka' 'Wilanowský palác']
#
# name:de: 109 unikalnych wartości
#     Przykładowe: ['Bank- und Finanzzentrum' 'Königsschloss' 'Kloster der Visitantinnen'
#  'Kultur- und Wissenschaftspalast'
#  'Ministerium für Entwicklung und Technologie']
#
# name:el: 10 unikalnych wartości
#     Przykładowe: ['Εθνική Βιβλιοθήκη της Πολωνίας' 'Εθνική Τράπεζα της Πολωνίας'
#  'Παλάτι του Βιλάνουφ' 'Εκκλησία της Αγίας Άννας' 'Κτήριο Α']
#
# name:es: 33 unikalnych wartości
#     Przykładowe: ['Castillo Real' 'Iglesia de San José Custodio'
#  'Palacio de la Cultura y la Ciencia'
#  'Ministerio de Desarrollo y Tecnología' 'Biblioteca Nacional de Polonia']
#
# name:eu: 1 unikalnych wartości
#     Przykładowe: ['Wilanów jauregia']
#
# name:fi: 8 unikalnych wartości
#     Przykładowe: ['Puolan kansalliskirjasto' 'Puolan kansallispankki' 'Wilanówin palatsi'
#  'Rakennus A' 'Oikeusministeriö']
#
# name:fr: 74 unikalnych wartości
#     Przykładowe: ['Palais royal' 'Palais de la Culture et de la Science'
#  'Ministère du Développement économique et de la Technologie'
#  'Bibliothèque nationale' 'Diète de la République de Pologne']
#
# name:he: 8 unikalnych wartości
#     Przykładowe: ['הספרייה הלאומית של פולין' 'ארמון וילאנוב' 'כנסיית סנט אנה' 'בניין A'
#  'כנסיית ישוע המשיח של קדושי אחרית הימים']
#
# name:hr: 7 unikalnych wartości
#     Przykładowe: ['Nacionalna knjižnica' 'Palača u Wilanówu' 'Zgrada A'
#  'Ministarstvo pravosuđa' 'Crkva Isusa Krista svetaca posljednjih dana']
#
# name:hy: 3 unikalnych wartości
#     Przykładowe: ['Լեհաստանի ազգային գրադարան' 'Վիլանովի պալատ'
#  'Հիսուս Քրիստոսի վերջին օրերի սրբերի եկեղեցի']
#
# name:id: 3 unikalnych wartości
#     Przykładowe: ['Bank Nasional Polandia' 'Istana Wilanów' 'Istana Presiden']
#
# name:it: 30 unikalnych wartości
#     Przykładowe: ['Castello Reale' 'Ministero dello Sviluppo e della Tecnologia'
#  'Biblioteca nazionale polacca' 'Camera dei deputati della Polonia'
#  "Ambasciata d'Italia"]
#
# name:ja: 15 unikalnych wartości
#     Przykładowe: ['ポーランド国立図書館' '国民教育省' '外務省' 'ポーランド国立銀行' '財務省']
#
# name:jv: 1 unikalnych wartości
#     Przykładowe: ['Istana Wilanów']
#
# name:ka: 3 unikalnych wartości
#     Przykładowe: ['პოლონეთის ეროვნული ბიბლიოთეკა' 'ვილანუვის სასახლე'
#  'ვარშავის უნივერსიტეტის აღმოსავლეთმცოდნეობის ფაკულტეტი']
#
# name:ko: 16 unikalnych wartości
#     Przykładowe: ['바르샤바 왕궁' '문화 과학 궁전' '폴란드 국립도서관' '빌라누프궁' '성 안네 성당']
#
# name:nl: 18 unikalnych wartości
#     Przykładowe: ['Nationale Bibliotheek van Polen' 'Ministerie van Buitenlandse Zaken'
#  'Nationale Bank van Polen' 'Wilanówpaleis' 'Sint-Annakerk']
#
# name:no: 12 unikalnych wartości
#     Przykładowe: ['Kongeslottet' 'Polens nasjonalbibliotek' 'Polens nasjonalbank'
#  'Wilanów-palasset' 'St. Anna kirke']
#
# name:pt: 14 unikalnych wartości
#     Przykładowe: ['Castelo Real' 'Palácio da Cultura e Ciência'
#  'Ministério do Desenvolvimento e Tecnologia'
#  'Biblioteca Nacional da Polónia' 'Palácio Wilanów']
#
# name:ro: 9 unikalnych wartości
#     Przykładowe: ['Biblioteca Națională a Poloniei' 'Banca Națională a Poloniei'
#  'Palatul Wilanów' 'Palatul lui Kazimierz' 'Clădirea A']
#
# name:tr: 5 unikalnych wartości
#     Przykładowe: ['Polonya Ulusal Kütüphanesi' 'Wilanów Sarayı' 'A Binası'
#  'Adalet Bakanlığı' 'Meçhul Asker Anıtı']
#
# name:vi: 9 unikalnych wartości
#     Przykładowe: ['Thư viện quốc gia Ba Lan' 'Cung điện Wilanów' 'Nhà thờ Thánh Anna'
#  'Tòa nhà A' 'Nhà thờ Ba Ngôi Thánh']
#
# name:zh: 18 unikalnych wartości
#     Przykładowe: ['波兰国家图书馆' '波兰共和国众议院' '波兰外交部' '波兰国家银行' '维拉诺宫']
#
# name:zh-Hant: 16 unikalnych wartości
#     Przykładowe: ['波蘭國家圖書館' '波蘭共和國眾議院' '波蘭外交部' '波蘭國家銀行' '維拉諾宮']
#
# start_date: 185 unikalnych wartości
#     Przykładowe: ['1955-07-21' '1930' '1972' '2013-03' '1910']
#
# toilets:wheelchair: 4 unikalnych wartości
#     Przykładowe: ['yes' 'designated' 'limited' 'no']
#
# wikidata: 1411 unikalnych wartości
#     Przykładowe: ['Q1756534' 'Q806604' 'Q756098' 'Q33547155' 'Q11687305']
#
# wikipedia: 597 unikalnych wartości
#     Przykładowe: ['pl:Zamek Ujazdowski w Warszawie'
#  'pl:Gmach dawnego Domu Partii w Warszawie'
#  'pl:Zamek Królewski w Warszawie'
#  'pl:Gmach Banku Gospodarstwa Krajowego w Warszawie'
#  'pl:Kamienica Mikołaja Szelechowa w Warszawie']
#
# addr:city:simc: 7 unikalnych wartości
#     Przykładowe: ['0918123' '919810' '0921728' '919884' '0005109']
#
# disused:amenity: 14 unikalnych wartości
#     Przykładowe: ['clinic' 'theatre' 'fast_food' 'school' 'hospital']
#
# old_name: 107 unikalnych wartości
#     Przykładowe: ['Warszawska Giełda Papierów Wartościowych'
#  'Biuro Programu Zostań Żołnierzem Rzeczypospolitej'
#  'Wyższa Szkoła Zarządzania i Przedsiębiorczości im. Bogdana Jańskiego'
#  'Ministerstwo Wyznań Religijnych i Oświecenia Publicznego'
#  'Gmach Najwyższej Izby Kontroli']
#
# source:addr: 17 unikalnych wartości
#     Przykładowe: ['gugik.gov.pl' 'mapa.um.warszawa.pl' 'msi' 'website' 'geoportal.gov.pl']
#
# capacity:disabled: 6 unikalnych wartości
#     Przykładowe: ['yes' '3' '6' '8' '11']
#
# capacity:parent: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# capacity:women: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# park_ride: 2 unikalnych wartości
#     Przykładowe: ['no' 'yes']
#
# parking: 5 unikalnych wartości
#     Przykładowe: ['multi-storey' 'garage' 'underground' 'street_side' 'surface']
#
# roof:shape: 19 unikalnych wartości
#     Przykładowe: ['flat' 'gabled' 'many' 'hipped' 'double_saltbox']
#
# supervised: 2 unikalnych wartości
#     Przykładowe: ['no' 'yes']
#
# surface: 7 unikalnych wartości
#     Przykładowe: ['concrete' 'paved' 'sand' 'asphalt' 'artificial_turf']
#
# outdoor_seating: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# source:ref:gez: 1 unikalnych wartości
#     Przykładowe: ['https://bip.warszawa.pl/NR/rdonlyres/0019e1b3/krwefycwmatxephysjucignibfynfqhx/GEZ_Aktualny_wykaz_zabytk%C3%B3w_20220203.pdf']
#
# changing_table: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# source:geometry: 11 unikalnych wartości
#     Przykładowe: ['geoportal.gov.pl:ortofoto' 'EGIB' 'EGiB'
#  'UM Warszawa:Cmentarze - Kwatery'
#  'Krajowa Integracja Ewidencji Gruntów: Budynki']
#
# toilets: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# note: 171 unikalnych wartości
#     Przykładowe: ['These are all parts of one building mapped according to http://wiki.osm.org/wiki/User:Jongleur/MultiLevel_Building_Shapes'
#  'UW wyniósł się z tej nieruchomości https://www.uw.edu.pl/nieruchomosc-przy-ul-nowy-swiat-4/'
#  'Bing skalibrowany do serii tracków GPS: -1.12; 2.89'
#  'Budynek należy do SGGW'
#  'Nie wiem, czemu wszystkie źródła podają adres pałacu 20A, w każdym razie to jest ten budynek. Adres do weryfikacji, zostaje zgodnie z Geoportalem.']
#
# source:building: 4 unikalnych wartości
#     Przykładowe: ['BDOT' 'EGiB'
#  'EGiB, http://wislanakepa.pl/images/inv/etap_II_podzial.jpg'
#  'EGiB, http://wislanakepa.pl/etap3/PZT etap III.jpg']
#
# building:material: 16 unikalnych wartości
#     Przykładowe: ['concrete' 'plaster' 'metal' 'stone' 'glass']
#
# building:use: 10 unikalnych wartości
#     Przykładowe: ['office' 'civic' 'residential' 'squat' 'museum']
#
# roof:material: 15 unikalnych wartości
#     Przykładowe: ['concrete' 'tar_paper' 'glass' 'granite' 'metal sheet']
#
# roof:orientation: 2 unikalnych wartości
#     Przykładowe: ['along' 'across']
#
# gas_insulated: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# rating: 6 unikalnych wartości
#     Przykładowe: ['2x40 MVA' '2x63 MVA' '2x400kVA' '630 kVA' '800 kVA']
#
# contact:website: 86 unikalnych wartości
#     Przykładowe: ['http://www.zoztargowek.waw.pl/?go=rem' 'http://www.ca.waw.pl'
#  'http://www.il.pw.edu.pl/' 'http://www.mimuw.edu.pl/'
#  'http://www.polon.uw.edu.pl/']
#
# addr:housename: 339 unikalnych wartości
#     Przykładowe: ['Gmach imienia profesora Władysława Stankiewicza'
#  'Gmach imienia profesora Eugeniusza Pijanowskiego'
#  'Gmach imienia profesora Franciszka Staffa' 'Szpital Medicover'
#  'Pałac Mostowskich']
#
# building:colour: 177 unikalnych wartości
#     Przykładowe: ['#9b9d97' '#C2B280' '#C6AE7F' '#CABC81' '#999282']
#
# roof:colour: 112 unikalnych wartości
#     Przykładowe: ['#666666' '#333333' '#5f6062' 'white' '#aa7766']
#
# wikimedia_commons: 39 unikalnych wartości
#     Przykładowe: ['File:Warszawa, ul. Krakowskie Przedmieście 42-44, Karowa 22 20170516 001.jpg'
#  'File:Hotel Europejski w Raffles Warszawie 2019.jpg'
#  'File:WEiTI_2009.JPG' 'File:FortWola.jpg'
#  'File:Klasztor Bernardynów na Czerniakowie.jpg']
#
# drive_through: 2 unikalnych wartości
#     Przykładowe: ['no' 'yes']
#
# fast_food: 1 unikalnych wartości
#     Przykładowe: ['cafeteria']
#
# height: 146 unikalnych wartości
#     Przykładowe: ['12' '9' '18' '25' '27']
#
# operator:type: 8 unikalnych wartości
#     Przykładowe: ['university' 'public' 'government' 'private' 'business']
#
# loc_name: 38 unikalnych wartości
#     Przykładowe: ['Biały Dom;Dom Partii;Dom pod Baranami' 'Sądy na Lesznie' 'Pekin'
#  'Alcatraz' 'FUW']
#
# ref:inspire: 23 unikalnych wartości
#     Przykładowe: ['PL.1.9.ZIPOZ.NID_N_14_BK.194021;PL.1.9.ZIPOZ.NID_E_14_BK.36082;PL.1.9.ZIPOZ.NID_E_14_BK.36088'
#  'PL.1.9.ZIPOZ.NID_N_14_BK.194019;PL.1.9.ZIPOZ.NID_E_14_BK.36128'
#  'PL.1.9.ZIPOZ.NID_N_14_BK.193936' 'PL.1.9.ZIPOZ.NID_N_14_BK.194116'
#  'PL.1.9.ZIPOZ.NID_N_14_BK.193950;PL.1.9.ZIPOZ.NID_E_14_BK.36100']
#
# short_name: 100 unikalnych wartości
#     Przykładowe: ['WG UW' 'PKiN' 'MRiT' 'DS Akademik' 'KRUS']
#
# faculty: 4 unikalnych wartości
#     Przykładowe: ['biology' 'archaeology' 'sociology' 'psychology']
#
# roof:levels: 10 unikalnych wartości
#     Przykładowe: ['1' '0' '2' '6' '3']
#
# contact:phone: 93 unikalnych wartości
#     Przykładowe: ['+48 22 633 91 54' '22 826 36 83' '+48 22 55 20 218' '+48 22 5520631'
#  '+48 22 603 22 01']
#
# name:ba: 1 unikalnych wartości
#     Przykładowe: ['Варшава университетының шәрҡиәт факультеты']
#
# name:la: 7 unikalnych wartości
#     Przykładowe: ['Bibliotheca Nationalis Polonica' 'Facultas Studiorum Orientalium'
#  'Universitas Medica Varsoviensis' 'Domus Dissentium'
#  'Ministerium Iustitiae']
#
# name:uz: 1 unikalnych wartości
#     Przykładowe: ['Varshava universitetining sharqshunoslik fakulteti']
#
# contact:email: 54 unikalnych wartości
#     Przykładowe: ['wnpism@uw.edu.pl' 'krp7warszawa@policja.waw.pl' 'instytut@itb.pl'
#  'sarna@osiedleprzyjazn.pl' 'jelonek@osiedleprzyjazn.pl']
#
# addr:country: 1 unikalnych wartości
#     Przykładowe: ['PL']
#
# payment:visa: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# covered: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# deanery: 27 unikalnych wartości
#     Przykładowe: ['Dekanat grochowski' 'Dekanat śródmiejski' 'Dekanat praski'
#  'Dekanat Staromiejski' 'Dekanat bielański']
#
# diocese: 7 unikalnych wartości
#     Przykładowe: ['Diecezja warszawsko-praska' 'Archidiecezja warszawska'
#  'Archidiecezja Warszawska'
#  'Diecezja warszawsko-praska;Archieparchia przemysko-warszawska'
#  'Ordynariat Polowy Wojska Polskiego;Archidiecezja warszawska']
#
# image: 105 unikalnych wartości
#     Przykładowe: ['https://commons.wikimedia.org/wiki/File:Ko%C5%9Bci%C3%B3%C5%82_%C5%9Bw._Patryka_w_Warszawie.jpg'
#  'http://commons.wikimedia.org/wiki/File:POL_Kosciol_sw_Anny_w_Warszawie_2008_%281%29.JPG'
#  'https://commons.wikimedia.org/wiki/File:PL_Warsaw_Groch%C3%B3w_sanktuar_mat_meczennik_00014.JPG'
#  'https://commons.wikimedia.org/wiki/File:6_Warszawa_054.jpg'
#  'https://commons.wikimedia.org/wiki/File:Zespol_kosciola_MB_Zwycieskiej_Warszawa_2011_(1).JPG']
#
# url: 53 unikalnych wartości
#     Przykładowe: ['https://youtu.be/IDIg7yvzAPU'
#  'http://diecezja.waw.pl/parafie/warszawa-goclaw-sw-patryka'
#  'http://diecezja.waw.pl/parafie/warszawa-grochow-mb-krolowej-polskich-meczennikow'
#  'http://diecezja.waw.pl/parafie/warszawa-kamionek-bozego-ciala'
#  'http://diecezja.waw.pl/parafie/warszawa-praga-najswietszego-serca-jezusowego']
#
# old_name_2: 1 unikalnych wartości
#     Przykładowe: ['Intraco II']
#
# alt_name:de: 6 unikalnych wartości
#     Przykładowe: ['Weißes Häuschen' 'Lesser-Palast' 'Natolin-Palais;Potocki-Palast'
#  'Jesuitenkirche' 'St.-Josephs-Kirche']
#
# man_made: 21 unikalnych wartości
#     Przykładowe: ['chimney' 'water_well' 'water_tower' 'wastewater_plant' 'tower']
#
# historic_name: 4 unikalnych wartości
#     Przykładowe: ['Kościół pw. św. Karola Boromeusza' 'Hala Targowa Mirowska (zachodnia)'
#  'Hala Targowa Mirowska (wschodnia)' 'Koszary Gwardii Konnej Koronnej']
#
# architect: 25 unikalnych wartości
#     Przykładowe: ['Lew Rudniew'
#  'Władysław Kozłowski;Apoloniusz Nieniewski;Ludwik Panczakiewicz;Bolesław Milkowski'
#  'Stefan Szyller' 'Arseniusz Romanowicz;Piotr Szymaniak'
#  'Fryderyk Albert Lessel']
#
# old_addr:housenumber: 461 unikalnych wartości
#     Przykładowe: ['15' '3/5' '43' '1' '8']
#
# old_addr:street: 145 unikalnych wartości
#     Przykładowe: ['Przejazd' 'Witolińska' 'Plac Żelaznej Bramy' 'Męcińska' 'Marszałkowska']
#
# air_conditioning: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# internet_access:fee: 3 unikalnych wartości
#     Przykładowe: ['no' 'customers' 'yes']
#
# internet_access:ssid: 4 unikalnych wartości
#     Przykładowe: ['*WestfieldMokotow_FreeWifi' 'CH ATRIUM Reduta [WiFi-Spot]' 'McD-Hotspot'
#  'KFC Hotspot']
#
# payment:apple_pay: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:contactless: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:google_pay: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:maestro: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:mastercard: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# smoking: 4 unikalnych wartości
#     Przykładowe: ['no' 'outside' 'isolated' 'separated']
#
# stroller: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# max_level: 6 unikalnych wartości
#     Przykładowe: ['1' '3' '6' '13' '2']
#
# min_level: 6 unikalnych wartości
#     Przykładowe: ['0' '-1' '2' '-2' '1']
#
# building:style: 1 unikalnych wartości
#     Przykładowe: ['neoclassical']
#
# contact:youtube: 8 unikalnych wartości
#     Przykładowe: ['https://www.youtube.com/user/ZamekKrolewski'
#  'https://www.youtube.com/user/PolandMFA'
#  'https://www.youtube.com/c/daswanna/featured'
#  'https://www.youtube.com/user/PolicjaPL'
#  'https://www.youtube.com/@parafiaewangelicko-reformo4043']
#
# name:be: 27 unikalnych wartości
#     Przykładowe: ['Каралеўскі замак' 'Палац Навукі і Культуры'
#  'Міністэрства развіцця і тэхналогій' 'Нацыянальная бібліятэка Польшчы'
#  'Сейм Рэспублікі Польшча']
#
# name:eo: 14 unikalnych wartości
#     Przykładowe: ['Reĝa Kastelo' 'Palaco de Kulturo kaj Scienco'
#  'Nacia Biblioteko de Pollando' 'Ambasadejo de Italio'
#  'Ministerio pri Financoj']
#
# fuel:GTL_diesel: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# fuel:adblue: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# fuel:diesel: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# fuel:lpg: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# fuel:octane_95: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# fuel:octane_98: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:dkv: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:uta: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# fax: 110 unikalnych wartości
#     Przykładowe: ['22 6125179' '+48 22 664 40 49' '+48 22 558 1235' '+48 22 827 18 21'
#  '+48 22 596 06 47']
#
# rooms: 20 unikalnych wartości
#     Przykładowe: ['733' '192' '414' '338' '74']
#
# stars: 5 unikalnych wartości
#     Przykładowe: ['5' '3' '4' '1' '2']
#
# church:type: 9 unikalnych wartości
#     Przykładowe: ['parish' 'auxiliary' 'rectoral' 'perpetual adoration' 'monastic']
#
# parish: 26 unikalnych wartości
#     Przykładowe: ['Parafia św. Barbary w Warszawie'
#  'Parafia pw. Świętych Apostołów Jana i Pawła'
#  'Parafia Najczystszego Serca Maryi w Warszawie'
#  'Parafia Matki Bożej Królowej Polskich Męczenników w Warszawie-Grochowie;Parafia greckokatolicka Opieki Najświętszej Maryi Panny w Warszawie'
#  'Parafia Ofiarowania Pańskiego w Warszawie']
#
# service_times: 47 unikalnych wartości
#     Przykładowe: ['Su 07:00,08:30,10:00,11:30,13:00,19:00; Mo-Sa 06:30,08:00,18:00; Sep-Jun Mo-Sa 07:30,15:00'
#  'We 17:00; Su 11:00'
#  'Su 07:00,08:30,10:00,11:30,13:00,17:30,19:00; Sep-Jun Su 11:30; May-Aug Su 20:00; Mo-Sa 06:30,08:00,09:00,18:00,19:00'
#  'Su 07:30,09:00,10:30,12:00,13:30,18:00; Mo-Sa 07:00,08:00,18:00'
#  'Su 10:30,19:00']
#
# abandoned: 2 unikalnych wartości
#     Przykładowe: ['yes' 'building']
#
# addr:unit: 11 unikalnych wartości
#     Przykładowe: ['B' 'III' 'C' 'E' 'C2']
#
# addr:flats: 24 unikalnych wartości
#     Przykładowe: ['11' '10' '7/1, 7/2, 7/3, 7/4' '5/1, 5/2, 5/3, 5/4' '3/1, 3/2, 3/3, 3/4']
#
# by:religious_title: 3 unikalnych wartości
#     Przykładowe: ['Pius XI' 'papież Jan Paweł II' 'papież Jan XXIII']
#
# date:religious_title: 4 unikalnych wartości
#     Przykładowe: ['1923' '2002' '1997' '1960']
#
# religious_title: 1 unikalnych wartości
#     Przykładowe: ['Bazylika Mniejsza']
#
# ref:ckkp: 8 unikalnych wartości
#     Przykładowe: ['MZ00762' 'MZ00496' 'MZ00406' 'MZ00373' 'MZ00424']
#
# was:brand: 1 unikalnych wartości
#     Przykładowe: ['Top Market']
#
# was:brand:wikidata: 1 unikalnych wartości
#     Przykładowe: ['Q9360044']
#
# was:name: 8 unikalnych wartości
#     Przykładowe: ['Loreal' 'Top Market' 'Muzeum Nowa Praga' 'Ambasada Libii' 'TrzyRzecze']
#
# was:opening_hours: 2 unikalnych wartości
#     Przykładowe: ['Mo-Fr 7:00-22:00; Sa 7:00-22:00; Su 9:00-21:00'
#  'Mo-Fr 05:00-19:00; Sa 06:00-14:00']
#
# was:shop: 8 unikalnych wartości
#     Przykładowe: ['supermarket' 'car_repair' 'convenience' 'yes' 'newsagent']
#
# source:office: 3 unikalnych wartości
#     Przykładowe: ['Baza teleadresowa jednostek KAS na dzień 13.12.2022'
#  'Baza teleadresowa administracji zespolonej według stanu na 16.08.2021'
#  'Baza teleadresowa jednostek KAS na dzień 12.02.2024']
#
# building:parts: 3 unikalnych wartości
#     Przykładowe: ['no' 'mixed' 'yes']
#
# toilets:access: 2 unikalnych wartości
#     Przykładowe: ['permissive' 'yes']
#
# healthcare: 14 unikalnych wartości
#     Przykładowe: ['doctor' 'clinic' 'hospital' 'blood_donation' 'dentist']
#
# brand:website: 3 unikalnych wartości
#     Przykładowe: ['https://frac.pl/' 'https://pizzadominium.pl/' 'https://baraboo.pl/']
#
# survey:date: 21 unikalnych wartości
#     Przykładowe: ['2021-06-19' '2021-09-02' '2022-01-23' '2021-06-25' '2021-03-13']
#
# craft: 14 unikalnych wartości
#     Przykładowe: ['tailor' 'upholsterer' 'key_cutter' 'shoemaker' 'carpenter']
#
# noname: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:bancomat: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:bankaxess: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# payment:coins: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:diners_club: 2 unikalnych wartości
#     Przykładowe: ['no' 'yes']
#
# payment:discover_card: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# payment:girocard: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# payment:jcb: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# payment:laser: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# payment:notes: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:visa_debit: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:visa_electron: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# 3dr:dormer: 1 unikalnych wartości
#     Przykładowe: ['c.c']
#
# 3dr:type: 2 unikalnych wartości
#     Przykładowe: ['2.0' '0.0']
#
# addr:city:en: 1 unikalnych wartości
#     Przykładowe: ['Warsaw']
#
# note:pl: 5 unikalnych wartości
#     Przykładowe: ['To są części tego samego budynku, zmapowane wg. http://wiki.osm.org/wiki/User:Jongleur/MultiLevel_Building_Shapes'
#  'TODO: ten budynek to siedziba różnych fundacji, organizacji itp. wszystko do zmapowania'
#  'dach do poprawki'
#  'To jest obrys wszystkich części budynku. Proszę nie kasuj go.'
#  'Osiedle Słoneczne Przedmieście']
#
# takeaway: 2 unikalnych wartości
#     Przykładowe: ['yes' 'only']
#
# disused: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# wikimedia_commons:category: 5 unikalnych wartości
#     Przykładowe: ['Category:Saint Anthony of Padua church in Warsaw-Czerniaków'
#  'Category:Sanctuary in Warszawa Siekierki'
#  'Category:Chapel of the Apparitions (Warszawa-Siekierki)'
#  'Category:Church_of_Our_Lady_Queen_of_the_Polish_Crown_in_Warsaw'
#  'Category:Monastic Fraternities of Jerusalem in Warsaw']
#
# historic:denomination: 1 unikalnych wartości
#     Przykładowe: ['orthodox;roman_catholic']
#
# atm: 2 unikalnych wartości
#     Przykładowe: ['no' 'yes']
#
# full_name: 3 unikalnych wartości
#     Przykładowe: ['Narodowy Bank Polski Oddział Okręgowy w Warszawie'
#  'Kuratorium Oświaty w Warszawie'
#  'Krzyż upamiętniający mszę świętą Jana Pawła II w dniu 2 czerwca 1979']
#
# source:name: 5 unikalnych wartości
#     Przykładowe: ['msi' 'uwaga #323006'
#  'https://eurobuildcee.com/news/55107-skomercjalizuja-life-building; https://www.bazabiur.pl/biuro-warszawa-life-building-atrium-tower.html'
#  'https://www.unipress.waw.pl/index.php?option=com_content&view=article&id=56%3Acontacts&catid=72%3Acontact&Itemid=18&lang=pl'
#  'https://csk.wat.edu.pl/']
#
# disused:operator: 1 unikalnych wartości
#     Przykładowe: ['Telekomunikacja Polska S.A.']
#
# isced:level: 6 unikalnych wartości
#     Przykładowe: ['2-3' '3' '1;2' '0' '4']
#
# ref:regon: 40 unikalnych wartości
#     Przykładowe: ['000799078' '000801504' '369738777' '146643118' '000799121']
#
# ref:rspo: 39 unikalnych wartości
#     Przykładowe: ['88064' '20653' '266908' '114158' '88066']
#
# ref:vatin: 23 unikalnych wartości
#     Przykładowe: ['PL5262131556' 'PL1131080804' 'PL1131903105' 'PL1131906049'
#  'PL1131884218']
#
# disused:tourism: 4 unikalnych wartości
#     Przykładowe: ['hotel' 'museum' 'gallery' 'hostel']
#
# wheelchair:description: 2 unikalnych wartości
#     Przykładowe: ['Das Hotel ist perfekt für Rollstuhlfahrer geeignet'
#  'podjazd wejście A, winda wejście A']
#
# old_addr:housenumber_2: 1 unikalnych wartości
#     Przykładowe: ['28/34']
#
# old_addr:street_2: 1 unikalnych wartości
#     Przykładowe: ['Nowogrodzka']
#
# name:ar: 11 unikalnych wartości
#     Przykładowe: ['وزارة التنمية الاقتصادية والتكنولوجيا' 'المكتبة الوطنية البولندية'
#  'مجلس النواب البولندي' 'وزارة الخارجية' 'البنك الوطني البولندي']
#
# name:lt: 10 unikalnych wartości
#     Przykładowe: ['Plėtros ir technologijų ministerija' 'Lenkijos nacionalinis bankas'
#  'Klimato ir aplinkos ministerija' 'Varšuvos medicinos universitetas'
#  'A pastatas']
#
# disused:office: 2 unikalnych wartości
#     Przykładowe: ['government' 'company']
#
# opening_hours:signed: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# indoor_seating: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# architect:wikipedia: 3 unikalnych wartości
#     Przykładowe: ['pl:Fryderyk Albert Lessel' 'pl:Adolf Schuch' 'pl:Józef Pius Dziekoński']
#
# trade: 2 unikalnych wartości
#     Przykładowe: ['building_supplies' 'plumbing']
#
# nohousenumber: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# townhall:type: 3 unikalnych wartości
#     Przykładowe: ['district' 'city' 'village']
#
# addr:place: 3 unikalnych wartości
#     Przykładowe: ['Plac Powstańców Warszawy' 'Plac Trzech Krzyży' 'Instytut Lotnictwa']
#
# name:csb: 6 unikalnych wartości
#     Przykładowe: ['Nôrodnô Bibloteka' 'Minysterstwò Nôrodny Edukacji'
#  'Nôrodny Pòlsczi Bank' 'Minysterstwo Dëtkòwiznë'
#  'Minysterstwò Cyfrizacji']
#
# capacity: 36 unikalnych wartości
#     Przykładowe: ['73' '7' '290' '405' '3']
#
# nursery: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# source:amenity: 3 unikalnych wartości
#     Przykładowe: ['Rejestr Żłobków na dzień 13.01.2023'
#  'Wykaz oddziałów i placówek Żandarmerii Wojskowej na dzień 30.12.2022'
#  'Rejestr domów pomocy społecznej województwa mazowieckiego stan na 10 maja 2024 r.']
#
# emergency: 5 unikalnych wartości
#     Przykładowe: ['no' 'defibrillator' 'control_centre' 'ambulance_station' 'water_tank']
#
# healthcare:speciality: 10 unikalnych wartości
#     Przykładowe: ['ophthalmology' 'first_aid' 'general' 'psychiatry'
#  'general;psychiatry;surgery;paediatrics;oncology;community;internal']
#
# addr:housename:de: 1 unikalnych wartości
#     Przykładowe: ['Villa Rau']
#
# country: 29 unikalnych wartości
#     Przykładowe: ['IT' 'CH' 'HU' 'TR' 'LV']
#
# diplomatic: 2 unikalnych wartości
#     Przykładowe: ['embassy' 'consulate']
#
# embassy: 2 unikalnych wartości
#     Przykładowe: ['yes' 'residence']
#
# target: 6 unikalnych wartości
#     Przykładowe: ['PL' 'PL;BG;RO' 'PL;LT;LV' 'PL;LT' 'PL;LT;LV;EE;UA']
#
# construction: 23 unikalnych wartości
#     Przykładowe: ['residential' 'office' 'school' 'apartments' 'retail']
#
# construction:start_date: 1 unikalnych wartości
#     Przykładowe: ['2023-11-08']
#
# opening_date: 9 unikalnych wartości
#     Przykładowe: ['2025-06' '2024-09-02' '2025-10-08' '2024-03-31' '2024-02']
#
# theatre:genre: 3 unikalnych wartości
#     Przykładowe: ['figure' 'philharmonic' 'drama']
#
# theatre:type: 2 unikalnych wartości
#     Przykładowe: ['concert_hall' 'amphi']
#
# name:hu: 10 unikalnych wartości
#     Przykładowe: ['Kultúra és Tudomány Palotája' 'Nemzeti Könyvtár' 'Külügyminisztérium'
#  'Lengyel Nemzeti Bank' 'Magyarország Nagykövetsége']
#
# alt_name:pl: 2 unikalnych wartości
#     Przykładowe: ['Pałac Lessera' 'Pałac Koniecpolskich (Radziwiłłów, Namiestnikowski)']
#
# house: 3 unikalnych wartości
#     Przykładowe: ['terraced' 'detached' 'twe']
#
# name:etymology:wikidata: 1 unikalnych wartości
#     Przykładowe: ['Q748124']
#
# name:etymology:wikipedia: 1 unikalnych wartości
#     Przykładowe: ['pl:Serce Maryi']
#
# operator:website: 3 unikalnych wartości
#     Przykładowe: ['https://www.parafia-szembeka.waw.pl/' 'https://ucsir.pl/'
#  'www.zlobki.waw.pl']
#
# website:ua: 1 unikalnych wartości
#     Przykładowe: ['https://warszawa19115.pl/dla-obywateli-ukrainy']
#
# name:sv: 7 unikalnych wartości
#     Przykładowe: ['Oliktänkande hus' 'Byggnad A' 'Justitieministeriet' 'Sveriges ambassad'
#  'Jesu Kristi kyrka av sista dagars heliga']
#
# operator:en: 2 unikalnych wartości
#     Przykładowe: ['SGH Warsaw School of Economics' 'City of Warsaw']
#
# name:az: 4 unikalnych wartości
#     Przykładowe: ['Polşa Milli Kitabxanası' 'Xarici İşlər Nazirliyi' 'Bina A'
#  'Frederik Şopen İnstitutu']
#
# name:bg: 7 unikalnych wartości
#     Przykładowe: ['Национална библиотека на Полша' 'Сейм на Република Полша'
#  'Национална банка на Полша' 'Сграда А' 'Министерство на правосъдието']
#
# name:bs: 4 unikalnych wartości
#     Przykładowe: ['Nacionalna biblioteka Poljske' 'Narodna banka Poljske' 'Zgrada A'
#  'Ministarstvo pravde']
#
# name:da: 5 unikalnych wartości
#     Przykładowe: ['Kongeslottet' 'Bygning A' 'Justitsministeriet'
#  'Jesu Kristi Kirke af Sidste Dages Hellige' 'Reformerte kirke']
#
# name:et: 4 unikalnych wartości
#     Przykładowe: ['Hoone A' 'Justiitsministeerium'
#  'Viimse Aja Pühade Jeesuse Kristuse Kirik' 'Reformeeritud kirik']
#
# name:is: 2 unikalnych wartości
#     Przykładowe: ['Bygging A' 'Kirkja Jesú Krists hinna síðari daga heilögu']
#
# name:lv: 7 unikalnych wartości
#     Przykładowe: ['Polijas Republikas Sejms' 'Ēka A' 'Latvijas Republikas Vēstniecība'
#  'Tieslietu ministrija' 'Poļu teātris']
#
# name:mk: 4 unikalnych wartości
#     Przykładowe: ['Национална библиотека на Полска' 'Народна банка на Полска' 'Зградата А'
#  'Министерство за правда']
#
# name:sk: 7 unikalnych wartości
#     Przykładowe: ['Ministerstvo rozvoja a technológie' 'Budova A'
#  'Ministerstvo spravodlivosti' 'Veľvyslanectvo Slovenskej republiky'
#  'Poľské divadlo']
#
# name:sl: 4 unikalnych wartości
#     Przykładowe: ['Narodna knjižnica' 'Zgradba A' 'Ministrstvo za pravosodje'
#  'Cerkev Jezusa Kristusa svetih iz poslednjih dni']
#
# name:sq: 5 unikalnych wartości
#     Przykładowe: ['Biblioteka Kombëtare e Polonisë' 'Ndërtesa A' 'Ministria e Drejtësisë'
#  'Kisha e Jezu Krishtit e Shenjtorëve të Ditëve të Mëvonshme'
#  'Pallati Presidencial']
#
# name:sr: 5 unikalnych wartości
#     Przykładowe: ['Национална библиотека Пољске' 'Зграда А' 'Министарство правде'
#  'Црква Исуса Христа светаца последњих дана' 'Амбасада Србије']
#
# name:th: 2 unikalnych wartości
#     Przykładowe: ['ตึก A' 'กระทรวงยุติธรรม']
#
# parcel_ref: 6 unikalnych wartości
#     Przykładowe: ['50/1' '50/9' '50/2' '50/4' '50/5']
#
# addr:source: 1 unikalnych wartości
#     Przykładowe: ['mapa.um.warszawa.pl']
#
# building:name: 5 unikalnych wartości
#     Przykładowe: ['Gmach Ministerstwa Wyznań Religijnych i Oświecenia Publicznego'
#  'Pałac Przebendowskich-Radziwiłłów' 'Pałac Raczyńskich' 'Szara Willa'
#  'Budynek C']
#
# building:wikipedia: 3 unikalnych wartości
#     Przykładowe: ['pl:Pałac Przebendowskich w Warszawie'
#  'pl:Budynek łazienek Teodozji Majewskiej'
#  'pl:Pałac Raczyńskich w Warszawie']
#
# internet_access:captive_portal: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# internet_access:password: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# railway: 6 unikalnych wartości
#     Przykładowe: ['signal_box' 'engine_shed' 'workshop' 'wash' 'crossing_box']
#
# railway:ref: 41 unikalnych wartości
#     Przykładowe: ['An' 'STP1' 'Gr4' 'WGT-11' 'Ec']
#
# building:architecture: 6 unikalnych wartości
#     Przykładowe: ['baroque' 'stalinist_neoclassicism' 'postmodern' 'deconstructivism'
#  'classic']
#
# contact:twitter: 7 unikalnych wartości
#     Przykładowe: ['https://twitter.com/Zamek_Krolewski' 'https://twitter.com/PalacKultury'
#  'https://twitter.com/MSZ_RP' 'https://twitter.com/op_freta'
#  'https://x.com/Policja_KSP']
#
# contact:fax: 28 unikalnych wartości
#     Przykładowe: ['+48 22 603 83 88' '+48 22 601 37 36' '+48 228366363' '+48 22 596 79 15'
#  '+48 22 596 79 01']
#
# financial: 1 unikalnych wartości
#     Przykładowe: ['bank']
#
# multiplehousenumbers: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# building:part: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# club: 5 unikalnych wartości
#     Przykładowe: ['banking' 'sport' 'art' 'youth_movement' 'community_centre']
#
# short_name:en: 1 unikalnych wartości
#     Przykładowe: ['WFC']
#
# roof:height: 21 unikalnych wartości
#     Przykładowe: ['7' '1' '0,5' '0.75' '0.4']
#
# sauna: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# seasonal: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# grades: 1 unikalnych wartości
#     Przykładowe: ['1-4']
#
# social_centre:for: 2 unikalnych wartości
#     Przykładowe: ['child' 'veteran']
#
# social_facility: 6 unikalnych wartości
#     Przykładowe: ['group_home' 'outreach' 'shelter' 'nursing_home' 'day_care']
#
# blood:plasma: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# blood:platelets: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# blood:whole: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# laundry_service: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# self_service: 3 unikalnych wartości
#     Przykładowe: ['no' 'yes' 'only']
#
# compressed_air: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# disused:name: 6 unikalnych wartości
#     Przykładowe: ['CMS' 'Norauto' 'sala egzaminów teoretycznych WORD ME.3'
#  'WORD Warszawa, Miejsce Egzaminowania 3 "Radarowa"'
#  'Miejskie Przedsiębiorstwo Taksówkowe Sp. z o.o.']
#
# museum: 4 unikalnych wartości
#     Przykładowe: ['military' 'history' 'art' 'science']
#
# mapillary: 5 unikalnych wartości
#     Przykładowe: ['https://www.youtube.com/channel/UCEiWEE1OW_HHNcAG730oCaQ'
#  '430782278093353' '819706538949710' '957798708341265' '1030486237988371']
#
# ele: 10 unikalnych wartości
#     Przykładowe: ['6' '157' '5' '4' '1']
#
# accor_ticket_acceptant: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# addr:street:sym_ul: 4 unikalnych wartości
#     Przykładowe: ['45566' '12991' '02390' '13554']
#
# church:id: 11 unikalnych wartości
#     Przykładowe: ['20619' '06601' '07387' '06564' '06525']
#
# parish:wikidata: 19 unikalnych wartości
#     Przykładowe: ['Q132462726' 'Q11805666' 'Q11803569' 'Q11804149' 'Q11808371']
#
# parish:wikipedia: 19 unikalnych wartości
#     Przykładowe: ['pl:Parafia Opieki Najświętszej Marii Panny w Warszawie'
#  'pl:Parafia Ofiarowania Pańskiego w Warszawie'
#  'pl:Parafia Katedralna św. Michała Archanioła i św. Floriana w Warszawie'
#  'pl:Parafia wojskowo-cywilna Matki Boskiej Ostrobramskiej w Warszawie'
#  'pl:Parafia św. Grzegorza Wielkiego w Warszawie']
#
# delivery: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# building:name:uk: 1 unikalnych wartości
#     Przykładowe: ['Палац Красінських']
#
# colour: 12 unikalnych wartości
#     Przykładowe: ['tan' 'green' 'pink' 'brown' 'white']
#
# source:ref: 1 unikalnych wartości
#     Przykładowe: ['https://bip.warszawa.pl/NR/rdonlyres/0019e1b3/krwefycwmatxephysjucignibfynfqhx/GEZ_Aktualny_wykaz_zabytk%C3%B3w_20220203.pdf']
#
# building:min_level: 5 unikalnych wartości
#     Przykładowe: ['0' '1' '-1' '3' '2']
#
# old_addr:housename: 3 unikalnych wartości
#     Przykładowe: ['Saturn' 'Taurus' 'Orion']
#
# police: 2 unikalnych wartości
#     Przykładowe: ['offices' 'storage']
#
# guest_house: 1 unikalnych wartości
#     Przykładowe: ['hostel']
#
# animal: 14 unikalnych wartości
#     Przykładowe: ['King Vulture'
#  'Parrots;Diamond Dove;Cockatoo;Java Sparrow;Laughing Kookaburra' 'owls'
#  'monkey' 'White-tailed Eagle']
#
# animal:pl: 4 unikalnych wartości
#     Przykładowe: ['Papugi;Gołąbek Diamentowy;Kakadu;Ryżowiec Siwy;Kukabura'
#  'Ibis Szkarłatny;Czapla Złotawa' 'pająki;bezkręgowce'
#  'Myszołów;Jastrząb;Krogulec']
#
# zoo: 2 unikalnych wartości
#     Przykładowe: ['aviary' 'birds']
#
# int_name: 6 unikalnych wartości
#     Przykładowe: ['Institute of Meteorology and Water Management - National Research Institute'
#  'Space Research Center of Polish Academy of Science'
#  'Royal Thai Embassy in Warsaw' "McDonald's"
#  'Posesja prywatna (dekretowa)']
#
# species:wikidata: 2 unikalnych wartości
#     Przykładowe: ['Q41960' 'Q232906']
#
# roof: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# railway:signal_box: 3 unikalnych wartości
#     Przykładowe: ['electronic' 'mechanical' 'electric']
#
# diet:vegetarian: 3 unikalnych wartości
#     Przykładowe: ['yes' 'only' 'no']
#
# beds: 2 unikalnych wartości
#     Przykładowe: ['90' '106']
#
# service:vehicle:tyres: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# min_height: 22 unikalnych wartości
#     Przykładowe: ['0' '4' '3.4' '2,5' '16']
#
# official_name:uk: 1 unikalnych wartości
#     Przykładowe: ['Польський театр імені Арнольда Шифмана']
#
# building:levels:underground: 5 unikalnych wartości
#     Przykładowe: ['1' '2' '4' '0' '3']
#
# consecrated: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# date:consecrated: 3 unikalnych wartości
#     Przykładowe: ['2003-06-01' '1901-09-29' '1999-12-24']
#
# shrine: 2 unikalnych wartości
#     Przykładowe: ['local' 'regional']
#
# shrine:name: 3 unikalnych wartości
#     Przykładowe: ['Sanktuarium Matki Boskiej Natolińskiej'
#  'Sanktuarium Miłosierdzia Bożego'
#  'Sanktuarium Matki Bożej Ostrobramskiej']
#
# shrine:type: 2 unikalnych wartości
#     Przykładowe: ['mary' 'lord']
#
# service: 8 unikalnych wartości
#     Przykładowe: ['dealer' 'parts;repair;tyres' 'aircraft_control' 'repair;parts'
#  'repair;tyres']
#
# service:vehicle:car_repair: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:vehicle:rv: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:vehicle:rv_repair: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# pipeline: 1 unikalnych wartości
#     Przykładowe: ['substation']
#
# note:loc_name: 1 unikalnych wartości
#     Przykładowe: ['Nazwa pochodzi od kształtu kopuły zwieńczającej budowlę']
#
# tower:type: 5 unikalnych wartości
#     Przykładowe: ['bell_tower' 'air_traffic_control_tower' 'observation' 'watchtower'
#  'lighting']
#
# website:2: 3 unikalnych wartości
#     Przykładowe: ['http://diecezja.waw.pl/parafie/warszawa-tarchomin-poraje-nmp-matki-pieknej-milosci'
#  'http://diecezja.waw.pl/parafie/warszawa-tarchomin-nowodwory-sw-franciszka-z-asyzu'
#  'http://diecezja.waw.pl/parafie/warszawa-pelcowizna-sw-jadwigi']
#
# recycling_type: 2 unikalnych wartości
#     Przykładowe: ['container' 'centre']
#
# source:operator: 1 unikalnych wartości
#     Przykładowe: ['survey']
#
# operator:abbr: 1 unikalnych wartości
#     Przykładowe: ['UCSIR']
#
# fuel:HGV_diesel: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# automated: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# diet:vegan: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# memorial: 3 unikalnych wartości
#     Przykładowe: ['war_memorial' 'cross' 'statue']
#
# monument:type: 1 unikalnych wartości
#     Przykładowe: ['eternal_flame']
#
# surveillance: 1 unikalnych wartości
#     Przykładowe: ['outdoor']
#
# surveillance:type: 1 unikalnych wartości
#     Przykładowe: ['guard']
#
# by:consecrated: 3 unikalnych wartości
#     Przykładowe: ['bp Aleksander Kakowski' 'bp Mikołaj Święcicki' 'bp Kazimierz Romaniuk']
#
# official_name:en: 3 unikalnych wartości
#     Przykładowe: ['Cathedral of St. Michael the Archangel and St. Florian the Martyr'
#  'Embassy of the Grand Duchy of Luxembourg'
#  'Embassy of the Islamic Republic of Afghanistan']
#
# name:sr-Latn: 2 unikalnych wartości
#     Przykładowe: ['Crkva Isusa Hrista svetaca posljednjih dana' 'Ambasada Srbije']
#
# roof:direction: 11 unikalnych wartości
#     Przykładowe: ['210' '97' '156.4' 'NE' 'SW']
#
# indoor: 4 unikalnych wartości
#     Przykładowe: ['yes' 'room' 'corridor' 'no']
#
# aeroway: 3 unikalnych wartości
#     Przykładowe: ['obstacle' 'terminal' 'hangar']
#
# telecom: 1 unikalnych wartości
#     Przykładowe: ['data_center']
#
# building:flats: 49 unikalnych wartości
#     Przykładowe: ['99' '71' '94' '150' '231']
#
# payment:blik: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:sodexo: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:v_pay: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# community_centre: 2 unikalnych wartości
#     Przykładowe: ['community_hall' 'youth_centre']
#
# community_centre:for: 3 unikalnych wartości
# ...
#     Przykładowe: ['stands' 'shed' 'tree' 'building']
#
# owner: 5 unikalnych wartości
#     Przykładowe: ['Union Investment' 'Deka Immobilien Investment'
#  'AMW Towarzystwo Budownictwa Społecznego “KWATERA” Sp. z o.o.' 'Ceraco'
#  'Iwona Święcińska']
#
# nat_name: 2 unikalnych wartości
#     Przykładowe: ['Wydział Inżynierii Materiałowej PW'
#  'Wydział Samochodów i Maszyn Roboczych']
#
# drive_in: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# microbrewery: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# toilets:disposal: 1 unikalnych wartości
#     Przykładowe: ['flush']
#
# toilets:handwashing: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# female:signed: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# male:signed: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# screen: 1 unikalnych wartości
#     Przykładowe: ['3']
#
# railway:local_operated: 2 unikalnych wartości
#     Przykładowe: ['no' 'yes']
#
# defensive_works: 1 unikalnych wartości
#     Przykładowe: ['barbican']
#
# service:vehicle:air_conditioning: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# disused:leisure: 2 unikalnych wartości
#     Przykładowe: ['adult_gaming_centre' 'swimming_pool']
#
# disabled:amenity: 1 unikalnych wartości
#     Przykładowe: ['place_of_worship']
#
# bell_tower: 1 unikalnych wartości
#     Przykładowe: ['campanile']
#
# bottle: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# generator:output:hot_air: 1 unikalnych wartości
#     Przykładowe: ['348 MW']
#
# generator:plant: 1 unikalnych wartości
#     Przykładowe: ['output']
#
# bench: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# public_transport: 1 unikalnych wartości
#     Przykładowe: ['station']
#
# tram: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# portable: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# shelter_type: 5 unikalnych wartości
#     Przykładowe: ['public_transport' 'picnic_shelter' 'gazebo' 'shopping_cart' 'lean_to']
#
# golf: 1 unikalnych wartości
#     Przykładowe: ['clubhouse']
#
# check_date:capacity: 1 unikalnych wartości
#     Przykładowe: ['2023-09-27']
#
# levels: 1 unikalnych wartości
#     Przykładowe: ['1']
#
# fuel:electricity: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# generator:output:electricity: 1 unikalnych wartości
#     Przykładowe: ['373 MW']
#
# hotel: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:bicycle:pump: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# fuel:octane_100: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# drinking_water: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# buildingpart: 1 unikalnych wartości
#     Przykładowe: ['verticalpassage']
#
# buildingpart:verticalpassage: 3 unikalnych wartości
#     Przykładowe: ['stairway;escalator' 'stairway' 'elevator']
#
# buildingpart:verticalpassage:floorrange: 1 unikalnych wartości
#     Przykładowe: ['0 to -1']
#
# tomb: 2 unikalnych wartości
#     Przykładowe: ['mausoleum' 'vault']
#
# agrarian: 1 unikalnych wartości
#     Przykładowe: ['tools']
#
# cemetery: 1 unikalnych wartości
#     Przykładowe: ['sector']
#
# utility: 3 unikalnych wartości
#     Przykładowe: ['power' 'gas' 'waste']
#
# source:opening_hours: 1 unikalnych wartości
#     Przykładowe: ['notes']
#
# contact:dobrymechanik: 1 unikalnych wartości
#     Przykładowe: ['https://dobrymechanik.pl/mechanicy/warszawa/evolution-service-2.html']
#
# contact:whatsapp: 1 unikalnych wartości
#     Przykładowe: ['+48 600 166 136']
#
# maxheight: 2 unikalnych wartości
#     Przykładowe: ['2.4' '4.5']
#
# maxwidth: 1 unikalnych wartości
#     Przykładowe: ['2.38']
#
# url:0: 2 unikalnych wartości
#     Przykładowe: ['https://fotopolska.eu/171659,obiekt.html?map_z=17'
#  'https://fotopolska.eu/3673,obiekt.html?map_z=18']
#
# was:railway: 1 unikalnych wartości
#     Przykładowe: ['signal_box']
#
# was:railway:ref: 1 unikalnych wartości
#     Przykładowe: ['WZD;WZP;WZS']
#
# was:railway:signal_box: 1 unikalnych wartości
#     Przykładowe: ['electric']
#
# disused:railway: 3 unikalnych wartości
#     Przykładowe: ['signal_box' 'coaling_tower' 'unloading_hole']
#
# disused:railway:ref: 1 unikalnych wartości
#     Przykładowe: ['Wr']
#
# disused:railway:signal_box: 1 unikalnych wartości
#     Przykładowe: ['electronic']
#
# elevator: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# name:ja-Latn: 1 unikalnych wartości
#     Przykładowe: ['Warushawa Chūō Eki']
#
# roof:angle: 1 unikalnych wartości
#     Przykładowe: ['98']
#
# maxheight:signed: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# recycling:cans: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# recycling:cardboard: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# recycling:electrical_appliances: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# recycling:paper: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# recycling:scrap_metal: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# dance:style: 1 unikalnych wartości
#     Przykładowe: ['argentine_tango']
#
# dance:teaching: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# phases: 1 unikalnych wartości
#     Przykładowe: ['3']
#
# transformer: 1 unikalnych wartości
#     Przykładowe: ['distribution']
#
# minor: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:vehicle:electrical: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:vehicle:engine_repair: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:vehicle:transmission: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:vehicle:wheels: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:vehicle:windshields: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# contact:mobile: 1 unikalnych wartości
#     Przykładowe: ['+48 668 110 043']
#
# instagram: 1 unikalnych wartości
#     Przykładowe: ['misianka.kawiarnia']
#
# pastry: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# building_1: 1 unikalnych wartości
#     Przykładowe: ['roof=permanent']
#
# disused:craft: 1 unikalnych wartości
#     Przykładowe: ['grinding_mill']
#
# payment:cryptocurrencies: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# payment:electronic_purses: 2 unikalnych wartości
#     Przykładowe: ['no' 'yes']
#
# nid:website: 1 unikalnych wartości
#     Przykładowe: ['https://zabytek.pl/pl/obiekty/zabytek?inspire_id=PL.1.9.ZIPOZ.NID_N_14_BK.434655&rejestr=rejestr-zabytkow']
#
# old_name:2015-2023: 1 unikalnych wartości
#     Przykładowe: ['Centrum Zarządzania Innowacjami i Transferem Technologii']
#
# natural: 1 unikalnych wartości
#     Przykładowe: ['grassland']
#
# pump: 2 unikalnych wartości
#     Przykładowe: ['yes' 'powered']
#
# ruins:building: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# roof:type: 1 unikalnych wartości
#     Przykładowe: ['flat']
#
# information: 1 unikalnych wartości
#     Przykładowe: ['office']
#
# payment:paypass: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# 3dr:height2: 1 unikalnych wartości
#     Przykładowe: ['0.45']
#
# bin: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# shelter: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# operator:official_name: 1 unikalnych wartości
#     Przykładowe: ['Samodzielny Publiczny Zakład Opieki Zdrowotnej Warszawa-Ursynów']
#
# type: 2 unikalnych wartości
#     Przykładowe: ['multipolygon' 'building']
#
# abandoned:generator:method: 1 unikalnych wartości
#     Przykładowe: ['combustion']
#
# abandoned:generator:output:hot_water: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# abandoned:generator:source: 1 unikalnych wartości
#     Przykładowe: ['coal']
#
# abandoned:power: 1 unikalnych wartości
#     Przykładowe: ['generator']
#
# payment: 1 unikalnych wartości
#     Przykładowe: ['2 zł']
#
# check_date:internet_access: 1 unikalnych wartości
#     Przykładowe: ['2025-01-13']
#
# reservation: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# building:walls: 2 unikalnych wartości
#     Przykładowe: ['brick' 'steel']
#
# service:vehicle:new_car_sales: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# attraction: 4 unikalnych wartości
#     Przykładowe: ['yes' 'animal' 'roller_coaster' 'carousel']
#
# condition: 1 unikalnych wartości
#     Przykładowe: ['not_working']
#
# lockable: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# organic: 1 unikalnych wartości
#     Przykładowe: ['only']
#
# disused:man_made: 1 unikalnych wartości
#     Przykładowe: ['pumping_station']
#
# alt_name:cs: 1 unikalnych wartości
#     Przykładowe: ['Palác Koniecpolských ve Varšavě']
#
# source:access: 1 unikalnych wartości
#     Przykładowe: ['https://www.prezydent.pl/kancelaria/komunikaty-kancelarii-prezydenta-rp/wznawiamy-wycieczki-w-palacu-prezydenckim,34613']
#
# source:description: 1 unikalnych wartości
#     Przykładowe: ['https://pl.wikipedia.org/wiki/Biuro_Operacji_Antyterrorystycznych']
#
# service:vehicle:tyres_repair: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# bakehouse: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# bakery: 1 unikalnych wartości
#     Przykładowe: ['armenian']
#
# fuel:cng: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# fuel:lng: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# was:addr:housenumber: 12 unikalnych wartości
#     Przykładowe: ['188B' '188' '95C/1' '26/30' '14/16']
#
# was:addr:street: 3 unikalnych wartości
#     Przykładowe: ['Jutrzenki' 'Przekorna' 'Badylarska']
#
# education: 1 unikalnych wartości
#     Przykładowe: ['centre']
#
# training: 1 unikalnych wartości
#     Przykładowe: ['computer']
#
# building:prefabricated: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# dispensing: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# generator:type: 1 unikalnych wartości
#     Przykładowe: ['gas_turbine']
#
# noexit: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# demolished:building:levels: 3 unikalnych wartości
#     Przykładowe: ['1' '3' '2']
#
# service:vehicle:body_repair: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# industrial: 1 unikalnych wartości
#     Przykładowe: ['distributor']
#
# wholesale: 2 unikalnych wartości
#     Przykładowe: ['building_supplies' 'electro']
#
# destroyed: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:wire_transfer: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# validate:ants:yellow: 1 unikalnych wartości
#     Przykładowe: ['ignore']
#
# old_addr:place: 1 unikalnych wartości
#     Przykładowe: ['Wolica']
#
# name:fa: 2 unikalnych wartości
#     Przykładowe: ['کتابخانه ملی لهستان' 'سفارت افغانستان']
#
# was:addr:city: 1 unikalnych wartości
#     Przykładowe: ['Warszawa']
#
# abandoned:railway: 1 unikalnych wartości
#     Przykładowe: ['signal_box']
#
# ownership: 1 unikalnych wartości
#     Przykładowe: ['private']
#
# heritage:ref: 1 unikalnych wartości
#     Przykładowe: ['PL.1.9.ZIPOZ.NID_N_14_BK.206330, PL.1.9.ZIPOZ.NID_E_14_BK.40012']
#
# was:building: 1 unikalnych wartości
#     Przykładowe: ['ruins']
#
# counselling_type: 1 unikalnych wartości
#     Przykładowe: ['education']
#
# construction:house: 1 unikalnych wartości
#     Przykładowe: ['terraced']
#
# railway:historic: 1 unikalnych wartości
#     Przykładowe: ['station']
#
# service:bicycle:retail: 2 unikalnych wartości
#     Przykładowe: ['yes' 'no']
#
# ref:de: 1 unikalnych wartości
#     Przykładowe: ['Gebäude J']
#
# ref:en: 1 unikalnych wartości
#     Przykładowe: ['Building J']
#
# ref:pl: 1 unikalnych wartości
#     Przykładowe: ['Budynek J']
#
# service:vehicle:car_parts: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# service:vehicle:suspension: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# motorcycle: 1 unikalnych wartości
#     Przykładowe: ['designated']
#
# motorcycle:theme: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# theme: 1 unikalnych wartości
#     Przykładowe: ['motorcycle']
#
# historic:railway: 1 unikalnych wartości
#     Przykładowe: ['engine_shed']
#
# payment:app: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:nfc: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# monitoring:gas: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# garden:type: 1 unikalnych wartości
#     Przykładowe: ['roof_garden']
#
# disused:cuisine: 1 unikalnych wartości
#     Przykładowe: ['pizza']
#
# product: 1 unikalnych wartości
#     Przykładowe: ['machinery']
#
# ref:nip: 1 unikalnych wartości
#     Przykładowe: ['1181872849']
#
# roller_coaster: 1 unikalnych wartości
#     Przykładowe: ['station']
#
# old_addr:flats: 2 unikalnych wartości
#     Przykładowe: ['1/2' '1/1']
#
# service:vehicle:muffler: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# recycling:glass: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# recycling:plastic: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# old_old_addr:housenumber: 1 unikalnych wartości
#     Przykładowe: ['1D']
#
# old_old_addr:street: 1 unikalnych wartości
#     Przykładowe: ['Juliana Konstantego Ordona']
#
# number_of_apartments: 1 unikalnych wartości
#     Przykładowe: ['23']
#
# construction:building: 1 unikalnych wartości
#     Przykładowe: ['train_station']
#
# playground: 1 unikalnych wartości
#     Przykładowe: ['playhouse']
#
# was:building:levels: 1 unikalnych wartości
#     Przykładowe: ['2']
#
# proposed:building:levels: 1 unikalnych wartości
#     Przykładowe: ['7']
#
# opening_hours:covid19: 1 unikalnych wartości
#     Przykładowe: ['off']
#
# source:position: 1 unikalnych wartości
#     Przykładowe: ['https://mapa.um.warszawa.pl/mapaApp1/mapa?service=mapa_wlasnosci;satelite;survey']
#
# bridge:support: 1 unikalnych wartości
#     Przykładowe: ['pier']
#
# monitoring:air_quality: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# recording:automated: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:mobile_app: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# regelbau: 1 unikalnych wartości
#     Przykładowe: ['514']
#
# coffee: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# recycling:furniture: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# bridge: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# addr:door: 3 unikalnych wartości
#     Przykładowe: ['19' '20' '18']
#
# website:menu: 1 unikalnych wartości
#     Przykładowe: ['https://www.maxpremiumburgers.pl/jedzenie/nasze-menu/']
#
# note:geometry: 1 unikalnych wartości
#     Przykładowe: ['Geometria mocno przybliżona na podstawie maxara']
#
# tag: 1 unikalnych wartości
#     Przykładowe: ['fixme']
#
# building:floor: 1 unikalnych wartości
#     Przykładowe: ['5']
#
# fuel:h35: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# fuel:h70: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# devices: 1 unikalnych wartości
#     Przykładowe: ['1']
#
# location:transition: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:account_cards: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:american_express: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# payment:mastercard_contactless: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# demolished:building: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# parcel_mail_in: 1 unikalnych wartości
#     Przykładowe: ['no']
#
# parcel_pickup: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# heating: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# brine_source: 1 unikalnych wartości
#     Przykładowe: ['Uzdrowisko w Ciechocinku odwiert nr 11']
#
# building:material:concrete: 1 unikalnych wartości
#     Przykładowe: ['panels']
#
# residential: 1 unikalnych wartości
#     Przykładowe: ['apartments']
#
# balcony: 1 unikalnych wartości
#     Przykładowe: ['yes']
#
# source:construction: 1 unikalnych wartości
#     Przykładowe: ['Sentinel-2']
#
# contact:tiktok: 1 unikalnych wartości
#     Przykładowe: ['https://www.tiktok.com/@royalcastleinwarsaw']
#
# building:shape: 1 unikalnych wartości
#     Przykładowe: ['tower']
#
# official_name:pl: 1 unikalnych wartości
#     Przykładowe: ['Pałac Kultury i Nauki']
#
# wikipedia:en: 1 unikalnych wartości
#     Przykładowe: ['Palace of Culture and Science, Warsaw']
#
# construction_date: 1 unikalnych wartości
#     Przykładowe: ['1901']
#
# name:af: 1 unikalnych wartości
#     Przykładowe: ['Nasionale Biblioteek van Pole']
#
# name:arz: 1 unikalnych wartości
#     Przykładowe: ['مكتبة بولاندا الوطنيه']
#
# name:udm: 1 unikalnych wartości
#     Przykładowe: ['Польшаысь Йӧскалык библиотека']
#
# name:zh-Hans: 1 unikalnych wartości
#     Przykładowe: ['波兰国家图书馆']
#
# disused:healthcare: 1 unikalnych wartości
#     Przykładowe: ['clinic']
#
# disused:official_name: 1 unikalnych wartości
#     Przykładowe: ['Centrum Medycyny Sportowej']
#
# disused:website: 1 unikalnych wartości
#     Przykładowe: ['https://cms.waw.pl/']
#
# area:highway: 1 unikalnych wartości
#     Przykładowe: ['footway']
#
# contact:flickr: 1 unikalnych wartości
#     Przykładowe: ['https://www.flickr.com/photos/polandmfa/']
#
# name:be-tarask: 1 unikalnych wartości
#     Przykładowe: ['Польскі народны банк']
#
# floors: 2 unikalnych wartości
#     Przykładowe: ['10;2' '2']

# %%
import osmnx as ox

# 1. Zdefiniuj obszar i tagi
place = "Warszawa, Polska"
tags = {
    "amenity": ["parcel_locker"],
    "highway": ["bus_stop"]
}

# 2. Pobierz dane
gdf = ox.features_from_place(place, tags)

# 3. Sprawdź dostępne kolumny
print("Dostępne kolumny w gdf:\n", gdf.columns.to_list())

# 4. Podziel na podzbiory
parcel_lockers = gdf[gdf["amenity"] == "parcel_locker"].copy()
bus_stops      = gdf[gdf["highway"] == "bus_stop"].copy()

# 5. Wybierz zestaw kolumn, który faktycznie istnieje
cols_to_show = ["osmid", "name", "operator", "brand", "ref", "public_transport", "geometry"]
available_parcel_cols = [c for c in cols_to_show if c in parcel_lockers.columns]
available_bus_cols    = [c for c in cols_to_show if c in bus_stops.columns]

# 6. Pokaż kilka pierwszych wierszy
print("\n=== Paczkomaty ===")
print(parcel_lockers[available_parcel_cols].head())

print("\n=== Przystanki autobusowe ===")
print(bus_stops[available_bus_cols].head())
# Out:
# Dostępne kolumny w gdf:
#  ['geometry', 'bench', 'bin', 'bus', 'highway', 'lit', 'name', 'network', 'network:wikidata', 'public_transport', 'ref', 'shelter', 'tactile_paving', 'url', 'wheelchair', 'network:wikipedia', 'departures_board', 'route_ref', 'layer', 'location', 'name:network:pks_grojec', 'name:network:wtp', 'ref:wtp', 'url:wtp', 'check_date:bench', 'old_name', 'name:network:pks_polonus', 'url:pks_grojec', 'url:pks_polonus', 'name:de', 'mapillary', 'wikidata', 'towards', 'survey:date', 'old_ref', 'check_date:shelter', 'start_date', 'check_date', 'check_date:lit', 'operator', 'covered', 'image', 'local_ref', 'passenger_information_display', 'tram', 'kerb', 'note', 'network:short', 'url:bkm_otwock', 'url:opgp', 'source', 'disused:highway', 'name:signed', 'request_stop', 'operator:type', 'todo', 'disused:public_transport', 'wikimedia_commons', 'check_date:bin', 'check_date:tactile_paving', 'amenity', 'brand', 'brand:wikidata', 'operator:wikidata', 'operator:wikipedia', 'parcel_mail_in', 'opening_hours', 'parcel_pickup', 'payment:blik', 'payment:paybylink', 'fixme', 'description', 'kerb:approach_aid', 'website', 'parcel_locker:type', 'payment:cards', 'not:network:wikidata', 'name:pl', 'shelter_type', 'surface', 'name:network:opgp', 'alt_name', 'name:network:gpa', 'ref:gpa', 'url:gpa', 'indoor', 'payment:inpost_mobile', 'level', 'payment:credit_cards', 'payment:debit_cards', 'currency:PLN', 'payment:american_express', 'payment:diners_club', 'payment:maestro', 'payment:mastercard', 'payment:visa', 'payment:visa_debit', 'payment:visa_electron', 'source:location', 'name:be', 'collection_times:signed', 'source:position', 'ref:zkm', 'url:zkm', 'addr:city', 'addr:housenumber', 'addr:postcode', 'addr:street', 'payment:wire_transfer', 'payment:contactless', 'payment:electronic_purses', 'refrigerated', 'addr:floor', 'app_operated', 'not:brand:wikidata', 'blind', 'height', 'payment:cash', 'surveillance', 'brand:wikipedia', 'direction', 'website:en', 'website:pl', 'website:ua', 'addr:unit', 'colour', 'physically_present', 'related:wikidata', 'internet_access', 'internet_access:fee', 'addr:door', 'addr:suburb', 'noname', 'phone', 'payment:none', 'outdoor_seating', 'addr:country', 'sign', 'link', 'building']
#
# === Paczkomaty ===
#                    name operator             brand      ref public_transport  \
# element id
# node    1328595335  NaN   InPost  Paczkomat InPost  WAW204M              NaN
#         1412655540  NaN   InPost  Paczkomat InPost   WAW16N              NaN
#         1860467670  NaN   InPost  Paczkomat InPost   WAW68A              NaN
#         1925690631  NaN   InPost  Paczkomat InPost  WAW327M              NaN
#         2025640560  NaN   InPost  Paczkomat InPost      NaN              NaN
#
#                                      geometry
# element id
# node    1328595335  POINT (21.04238 52.17507)
#         1412655540   POINT (21.0911 52.22096)
#         1860467670  POINT (21.09522 52.23292)
#         1925690631   POINT (21.0329 52.17308)
#         2025640560  POINT (20.93947 52.23772)
#
# === Przystanki autobusowe ===
#                                   name operator brand     ref  \
# element id
# node    162220858         PKP Ursus 15      NaN   NaN  421715
#         259568229  Ursynów Północny 06      NaN   NaN  312006
#         297209643           Rozbrat 06      NaN   NaN  707106
#         309168144           Marysin 03      NaN   NaN  206403
#         312081255           Magiera 01      NaN   NaN  608701
#
#                   public_transport                   geometry
# element id
# node    162220858         platform  POINT (20.88302 52.19451)
#         259568229         platform  POINT (21.03698 52.16198)
#         297209643         platform   POINT (21.0368 52.22195)
#         309168144         platform    POINT (21.156 52.24045)
#         312081255         platform  POINT (20.95026 52.27127)

# %%
parcel_lockers["brand_filled"] = parcel_lockers["brand"].fillna("Unknown")

# 2. Policz liczbę paczkomatów w podziale na brand
brand_counts = (
    parcel_lockers["brand_filled"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "brand", "brand_filled": "count"})
)

print(brand_counts)
# Out:
#                      count  count
# 0         Paczkomat InPost    972
# 1          Allegro One Box    205
# 2       DPD Pickup Station    116
# 3             Orlen Paczka     94
# 4                      DPD     52
# 5                  Allegro     49
# 6              DHL Pop Box     48
# 7                  Unknown     29
# 8          Appkomat InPost     27
# 9                   InPost     26
# 10                   Orlen     21
# 11                     DHL     20
# 12              AliExpress     15
# 13       Lodówkomat InPost      9
# 14                 Pocztex      7
# 15            DHL BOX 24/7      4
# 16           Poczta Polska      3
# 17              DPD Pickup      2
# 18    Pralniomat Q2 Pranie      2
# 19                 Cainiao      2
# 20                 SwipBox      2
# 21                   mebox      1
# 22                 arif.pl      1
# 23               Paczkomat      1
# 24     DPD Ppickup Station      1
# 25             DHL POP BOX      1
# 26          Allegro OneBox      1
# 27        DPD Pickup Point      1
# 28     Automat DHL POP BOX      1
# 29                CastoMat      1
# 30  Szybkomat Leroy Merlin      1
# 31                 DHL BOX      1

# %%
# Załóżmy, że masz już GeoDataFrame `parcel_lockers`
# z kolumną 'brand' zawierającą surowe nazwy.

def categorize_brand(b):
    """Przyporządkuj nazwę do jednej z głównych marek lub 'Inne'."""
    if not isinstance(b, str):
        return "Inne"
    s = b.lower().replace('.', '').replace(',', '').strip()
    if "inpost" in s:
        return "InPost"
    if "dhl" in s:
        return "DHL"
    if "allegro" in s:
        return "Allegro"
    if "dpd" in s:
        return "DPD"
    if "orlen" in s:
        return "Orlen"
    if "aliexpress" in s:
        return "Aliexpress"
    if "poczta" in s and "polska" in s:
        return "Poczta Polska"
    return "Inne"

# 1) Tworzymy nową kolumnę z kategorią
parcel_lockers['brand_category'] = (
    parcel_lockers['brand']
    .fillna('')            # NaN → pusty string
    .apply(categorize_brand)
)

# 2) Grupujemy i zliczamy
brand_counts = (
    parcel_lockers['brand_category']
    .value_counts()
    .reset_index()
    .rename(columns={'index': 'brand', 'brand_category': 'count'})
)

print(brand_counts)
# Out:
#            count  count
# 0         InPost   1034
# 1        Allegro    255
# 2            DPD    172
# 3          Orlen    115
# 4            DHL     75
# 5           Inne     47
# 6     Aliexpress     15
# 7  Poczta Polska      3

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd

# Funkcja kategoryzacji marki
def categorize_brand(b):
    if not isinstance(b, str):
        return "Inne"
    s = b.lower().replace('.', '').replace(',', '').strip()
    if "inpost" in s:
        return "InPost"
    if "dhl" in s:
        return "DHL"
    if "allegro" in s:
        return "Allegro"
    if "dpd" in s:
        return "DPD"
    if "orlen" in s:
        return "Orlen"
    if "aliexpress" in s:
        return "Aliexpress"
    if "poczta" in s and "polska" in s:
        return "Poczta Polska"
    return "Inne"

# Lista miast
cities = [
    "Warszawa, Polska", "Wrocław, Polska", "Łódź, Polska",
    "Poznań, Polska", "Białystok, Polska", "Gdańsk, Polska",
    "Bydgoszcz, Polska"
]

all_lockers = []
for city in cities:
    # 1) Pobranie paczkomatów w danym mieście
    tags = {"amenity": ["parcel_locker"]}
    gdf = ox.features_from_place(city, tags)
    lockers = gdf[gdf["amenity"] == "parcel_locker"].copy()
    
    # 2) Kategoryzacja brandu
    lockers["brand_category"] = lockers["brand"].fillna("").apply(categorize_brand)
    
    # 3) Dodanie kolumny 'city'
    lockers["city"] = city.split(",")[0]
    
    # 4) Wybór tylko potrzebnych kolumn
    all_lockers.append(lockers[["brand_category", "city", "geometry"]])

# 5) Połączenie w jeden GeoDataFrame
result_gdf = gpd.GeoDataFrame(
    pd.concat(all_lockers, ignore_index=True),
    crs="EPSG:4326"
)

# Rzut oka na wynik
print(result_gdf.head())
print("Łącznie paczkomatów pobranych:", len(result_gdf))
# Out:
#   brand_category      city                   geometry
# 0         InPost  Warszawa  POINT (21.04238 52.17507)
# 1         InPost  Warszawa   POINT (21.0911 52.22096)
# 2         InPost  Warszawa  POINT (21.09522 52.23292)
# 3         InPost  Warszawa   POINT (21.0329 52.17308)
# 4         InPost  Warszawa  POINT (20.93947 52.23772)
# Łącznie paczkomatów pobranych: 5221

# %%
# 1) Stwórz kolumny lat/lon z geometrii
result_gdf["lon"] = result_gdf.geometry.x
result_gdf["lat"] = result_gdf.geometry.y

# 2) Wybierz kolumny do zapisu (bez obiektu geometry)
df_to_csv = result_gdf.drop(columns="geometry")

# 3) Zapisz do CSV
df_to_csv.to_csv("paczkomaty_by_brand_city.csv", index=False)

print("Zapisano plik paczkomaty_by_brand_city.csv, liczba wierszy:", len(df_to_csv))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 1) Stwórz kolumny lat/lon z geometrii
# ----> 2 result_gdf["lon"] = result_gdf.geometry.x
#       3 result_gdf["lat"] = result_gdf.geometry.y
#       5 # 2) Wybierz kolumny do zapisu (bez obiektu geometry)
#
# File ~/learning/zadanko_python/mastercard_hackathon/venv/lib/python3.13/site-packages/geopandas/geoseries.py:281, in GeoSeries.x(self)
#     255 @property
#     256 def x(self) -> Series:
#     257     """Return the x location of point geometries in a GeoSeries
#     258
#     259     Returns
#    (...)    279
#     280     """
# --> 281     return _delegate_property("x", self)
#
# File ~/learning/zadanko_python/mastercard_hackathon/venv/lib/python3.13/site-packages/geopandas/base.py:83, in _delegate_property(op, this)
#      80 def _delegate_property(op, this):
#      81     # type: (str, GeoSeries) -> GeoSeries/Series
#      82     a_this = GeometryArray(this.geometry.values)
# ---> 83     data = getattr(a_this, op)
#      84     if isinstance(data, GeometryArray):
#      85         from .geoseries import GeoSeries
#
# File ~/learning/zadanko_python/mastercard_hackathon/venv/lib/python3.13/site-packages/geopandas/array.py:1123, in GeometryArray.x(self)
#    1121 else:
#    1122     message = "x attribute access only provided for Point geometries"
# -> 1123     raise ValueError(message)
#
# ValueError: x attribute access only provided for Point geometries

# %%
# Przykład: przystanki autobusowe
tags_bus_stops = {"highway": "bus_stop"}
bus_stops = get_osm_data("Warszawa, Polska", tags_bus_stops)

# Przykład: sklepy convenience (Żabka i podobne)
tags_convenience = {"shop": "convenience"}
convenience_stores = get_osm_data("Warszawa, Polska", tags_convenience)

# Przykład: parkingi
tags_parking = {"amenity": "parking"}
parkings = get_osm_data("Warszawa, Polska", tags_parking)

# Wyświetlenie liczby wyników
print("Liczba paczkomatów:", len(parcel_lockers))
print("Liczba przystanków:", len(bus_stops))
print("Liczba sklepów convenience:", len(convenience_stores))
print("Liczba parkingów:", len(parkings))

# 🗺️ Przykładowa wizualizacja
fig, ax = plt.subplots(figsize=(10, 10))
parcel_lockers.plot(ax=ax, color='red', markersize=10, label='Paczkomaty')
bus_stops.plot(ax=ax, color='blue', markersize=5, label='Przystanki')
convenience_stores.plot(ax=ax, color='green', markersize=5, label='Sklepy convenience')
parkings.plot(ax=ax, color='orange', markersize=5, label='Parking')

plt.legend()
plt.title("Wybrane obiekty OSM w Warszawie")
plt.show()
